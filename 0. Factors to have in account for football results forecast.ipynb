# %% [markdown]
# ## What can influence a soccer game result?
# - which team has the best players
# - which team has the best coach
# - which players are available for a concrete match
# - who is playing at home
# - how many days since last game (fatigue)
# - luck
# - market value of the club
# - table position last year
# - average table position last 3 years
# - results of last 5 games
# - rivalry between teams
# - weather
# - referree
# - head to head records
# - styles of play
# - discipline (red cards)
# - goals scored by the team
